# %%
import time
print(time.ctime())
# %load_ext ipydex.displaytools

import sympy as sp
from sympy.interactive import printing
printing.init_printing()

import symbtools as st
# Out:
# Fri Jul 26 00:03:34 2019

# %%
xx = st.symb_vector("x1:8") ##:T
# Out:
# xx.T := [x₁  x₂  x₃  x₄  x₅  x₆  x₇]
# ---

# %%
coeff_gen = sp.numbered_symbols("c")


poly, coeff_vect = st.poly_scalar_field(xx, coeff_gen, orders=[0, 1, 2, 3])

# %%
poly
# Out:
#                                 3          2             2             2
# c₀ + c₁⋅x₁ + c₁₀⋅x₁⋅x₃ + c₁₀₀⋅x₄  + c₁₀₁⋅x₄ ⋅x₅ + c₁₀₂⋅x₄ ⋅x₆ + c₁₀₃⋅x₄ ⋅x₇ +
#
#           2                                             2
# c₁₀₄⋅x₄⋅x₅  + c₁₀₅⋅x₄⋅x₅⋅x₆ + c₁₀₆⋅x₄⋅x₅⋅x₇ + c₁₀₇⋅x₄⋅x₆  + c₁₀₈⋅x₄⋅x₆⋅x₇ + c₁
#
#         2                      3          2             2                2
# ₀₉⋅x₄⋅x₇  + c₁₁⋅x₁⋅x₄ + c₁₁₀⋅x₅  + c₁₁₁⋅x₅ ⋅x₆ + c₁₁₂⋅x₅ ⋅x₇ + c₁₁₃⋅x₅⋅x₆  + c
#
#                          2          3          2                2          3
# ₁₁₄⋅x₅⋅x₆⋅x₇ + c₁₁₅⋅x₅⋅x₇  + c₁₁₆⋅x₆  + c₁₁₇⋅x₆ ⋅x₇ + c₁₁₈⋅x₆⋅x₇  + c₁₁₉⋅x₇  +
#
#                                            2
#  c₁₂⋅x₁⋅x₅ + c₁₃⋅x₁⋅x₆ + c₁₄⋅x₁⋅x₇ + c₁₅⋅x₂  + c₁₆⋅x₂⋅x₃ + c₁₇⋅x₂⋅x₄ + c₁₈⋅x₂⋅
#
#                                            2
# x₅ + c₁₉⋅x₂⋅x₆ + c₂⋅x₂ + c₂₀⋅x₂⋅x₇ + c₂₁⋅x₃  + c₂₂⋅x₃⋅x₄ + c₂₃⋅x₃⋅x₅ + c₂₄⋅x₃⋅
#
#                        2                                                     2
# ...

# %%
# matlab/octave code

sp.printing.octave_code(poly)
# Out:
# 'c0 + c1.*x1 + c10.*x1.*x3 + c100.*x4.^3 + c101.*x4.^2.*x5 + c102.*x4.^2.*x6 + c103.*x4.^2.*x7 + c104.*x4.*x5.^2 + c105.*x4.*x5.*x6 + c106.*x4.*x5.*x7 + c107.*x4.*x6.^2 + c108.*x4.*x6.*x7 + c109.*x4.*x7.^2 + c11.*x1.*x4 + c110.*x5.^3 + c111.*x5.^2.*x6 + c112.*x5.^2.*x7 + c113.*x5.*x6.^2 + c114.*x5.*x6.*x7 + c115.*x5.*x7.^2 + c116.*x6.^3 + c117.*x6.^2.*x7 + c118.*x6.*x7.^2 + c119.*x7.^3 + c12.*x1.*x5 + c13.*x1.*x6 + c14.*x1.*x7 + c15.*x2.^2 + c16.*x2.*x3 + c17.*x2.*x4 + c18.*x2.*x5 + c19.*x2.*x6 + c2.*x2 + c20.*x2.*x7 + c21.*x3.^2 + c22.*x3.*x4 + c23.*x3.*x5 + c24.*x3.*x6 + c25.*x3.*x7 + c26.*x4.^2 + c27.*x4.*x5 + c28.*x4.*x6 + c29.*x4.*x7 + c3.*x3 + c30.*x5.^2 + c31.*x5.*x6 + c32.*x5.*x7 + c33.*x6.^2 + c34.*x6.*x7 + c35.*x7.^2 + c36.*x1.^3 + c37.*x1.^2.*x2 + c38.*x1.^2.*x3 + c39.*x1.^2.*x4 + c4.*x4 + c40.*x1.^2.*x5 + c41.*x1.^2.*x6 + c42.*x1.^2.*x7 + c43.*x1.*x2.^2 + c44.*x1.*x2.*x3 + c45.*x1.*x2.*x4 + c46.*x1.*x2.*x5 + c47.*x1.*x2.*x6 + c48.*x1.*x2.*x7 + c49.*x1.*x3.^2 + c5.*x5 + c5
# ...

# %%
len(coeff_vect)
# Out:
# 120

# %%
printing.init_printing(0)
list(coeff_vect)
# Out:
# [c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, c39, c40, c41, c42, c43, c44, c45, c46, c47, c48, c49, c50, c51, c52, c53, c54, c55, c56, c57, c58, c59, c60, c61, c62, c63, c64, c65, c66, c67, c68, c69, c70, c71, c72, c73, c74, c75, c76, c77, c78, c79, c80, c81, c82, c83, c84, c85, c86, c87, c88, c89, c90, c91, c92, c93, c94, c95, c96, c97, c98, c99, c100, c101, c102, c103, c104, c105, c106, c107, c108, c109, c110, c111, c112, c113, c114, c115, c116, c117, c118, c119]
